# %%
# 1. Instalamos librerías base
# !pip install -q pygit2==1.15.1

# 2. Reemplazamos las versiones conflictivas de Colab
# !pip uninstall -y -q numpy cupy-cuda12x
# !pip install -q "numpy<2" cupy-cuda12x

# 3. Descargamos Fooocus (solo si no existe ya en tu entorno)
import os
# %cd /content
if not os.path.exists('/content/Fooocus'):
    print("Clonando el repositorio de Fooocus...")
    # !git clone https://github.com/lllyasviel/Fooocus.git
else:
    print("La carpeta Fooocus ya existe. ¡Listo para continuar!")

print("\n" + "="*50)
print("✅ PREPARACIÓN LISTA.")
print("⚠️ IMPORTANTE: Ve a 'Entorno de ejecución' > 'Reiniciar sesión' ANTES de pasar a la Celda 2.")
print("="*50)
